# %%
# !python run.py\
--model_type lgb\
--filename exp015\
--n_splits
# Out:
# ====== CV score ======
# 0.6682584840479577 (threshold: 0.33)
# ...
# Making fold: 100%|██████████| 97/97 [00:24<00:00,  3.94it/s]
#
# ...
# 100%|██████████| 97/97 [03:17<00:00,  2.04s/it]
#
# ...
#  44%|████▎     | 87/200 [01:03<01:25,  1.32it/s]
# ====== CV score ======
# 0.6682584840479577 (threshold: 0.33)
# ...
# Making fold: 100%|██████████| 97/97 [00:32<00:00,  2.97it/s]
#
# ...
# 100%|██████████| 97/97 [02:52<00:00,  1.78s/it]
#
# ...
#  44%|████▎     | 87/200 [00:35<00:42,  2.69it/s]
